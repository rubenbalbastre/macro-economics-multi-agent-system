# %%
from sys import path
import yaml
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

path.append("../src/")

from utils import format_messages
# from app import MacroAgent

# compilation config
checkpointer = InMemorySaver()
compile_config = {'checkpointer': checkpointer}

# llm config
llm_config = yaml.safe_load(open("config/llm.yaml", "rb"))

# app
app = MacroAgent(
    llm_config=llm_config,
    compile_config=compile_config
)

# %%
# from IPython.display import Image, display

# display(Image(app.compiled_graph.get_graph(xray=True).draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "scoping-session-1", "recursion_limit": 100}}
user_query = "Who is US President?"
result = await app.ainvoke(
    input={"user_query": user_query, "messages": [HumanMessage(content=user_query)]},
    config=config
)
format_messages(result['messages'])
# Out:
# GetCurrentState content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 636, 'total_tokens': 658, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CiltK6AEB9J6FAlJR5MFtrH1YSUa6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--f191f149-d978-41f8-b68b-19b2e179d0c2-0' tool_calls=[{'name': 'ConductResearch', 'args': {'research_topic': 'current US President December 2025'}, 'id': 'call_AS7kZuC5w3LSxI5D1mIKGfTv', 'type': 'tool_call'}] usage_metadata={'input_tokens': 636, 'output_tokens': 22, 'total_tokens': 658, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# GetCurrentState content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 118, 'prompt_tokens': 915, 'total_tokens': 1033, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-Ciltd0SYMrHtMfRCHAOpmrbqfcTBz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--77df8f57-6cdb-43c7-85c7-1cba26d61bd0-0' tool_calls=[{'name': 'think_tool', 'args': {'reflection': '1. Analysis of current findings - I found that Donald Trump is the current President of the United States, having taken office on January 20, 2025. There are recent reports about his activities, including a meeting regarding Venezuela. \n2. Gap assessment - There is no crucial information missing regarding who the current president is. \n3. Quality evaluation - I have sufficient evidence to confirm that Donald Trump is the president. \n4. Strategic decision - I have enough information to provide a complete answer.'}, 'id': 'call_T3DOXGmWkCOJhS5KvtW2Y2SW', 'type': 'tool_call'}] usage_metadata={'input_tokens': 915, 'output_tokens': 118, 'total_tokens': 1033, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# GetCurrentState content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 1176, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-Cilti7APYKTziEtHqtAONlR5dmSzY', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--8ad7de5e-d65f-489f-813e-ea68b9ee4fb9-0' tool_calls=[{'name': 'ResearchComplete', 'args': {}, 'id': 'call_aFaNnFms0wjuf1yzB3XsgyjL', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1176, 'output_tokens': 11, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# GetFutureEvents content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 798, 'total_tokens': 821, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-Ciltlyl5NCsBa4v5gbrVflPmqTe18', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--cb34b269-2c0c-449e-91bd-d620037ec95f-0' tool_calls=[{'name': 'ConductResearch', 'args': {'research_topic': 'upcoming economic events December 2025'}, 'id': 'call_SSCPbdAl6CPZGY9m4YD8m2sb', 'type': 'tool_call'}] usage_metadata={'input_tokens': 798, 'output_tokens': 23, 'total_tokens': 821, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# GetFutureEvents content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 212, 'prompt_tokens': 2283, 'total_tokens': 2495, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CiluvdXTk3FO6ql5MIUiZs6CBxvUT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--e994e312-5f8b-4d9e-9c3d-f8d47611c62f-0' tool_calls=[{'name': 'think_tool', 'args': {'reflection': "1. Analysis of current findings: I found a comprehensive list of upcoming economic events in December 2025, including key meetings of the Federal Reserve and other central banks, important economic reports, and financial conferences. Notably, the FOMC meeting will be crucial for determining interest rates and economic projections, which could significantly impact the economy. Additionally, the Bank of England's Financial Stability Report will address systemic risks in the UK financial system. \n\n2. Gap assessment: While I have a good overview of the scheduled events, I still need to assess how these events might specifically impact the macroeconomic landscape, such as potential market reactions or implications for economic policy. \n\n3. Quality evaluation: I have sufficient evidence and examples of upcoming events to provide a basic answer regarding future events that might affect the current economic status. \n\n4. Strategic decision: I should summarize the findings and provide an answer, as I have gathered enough information to address the query comprehensively."}, 'id': 'call_EyVXjJwLTzHynR67tdJOLYKu', 'type': 'tool_call'}] usage_metadata={'input_tokens': 2283, 'output_tokens': 212, 'total_tokens': 2495, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# GetFutureEvents content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 2699, 'total_tokens': 2710, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2432}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-Cilv2eSCKruDSkhJK7N5fFtNK5rSf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--282027de-f71f-4d34-b8ce-608aa89f7847-0' tool_calls=[{'name': 'ResearchComplete', 'args': {}, 'id': 'call_wQvqBKqoWWJQ73Hz5hu2L56V', 'type': 'tool_call'}] usage_metadata={'input_tokens': 2699, 'output_tokens': 11, 'total_tokens': 2710, 'input_token_details': {'audio': 0, 'cache_read': 2432}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ Who is US President?                                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "current US President December 2025"                                                        │
# │ }                                                                                                               │
# │    ID: call_AS7kZuC5w3LSxI5D1mIKGfTv                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ - Query: "current US President December 2025"                                                                   │
# │                                                                                                                 │
# │ **Fully Comprehensive Findings**                                                                                │
# │                                                                                                                 │
# │ President Donald Trump will hold a meeting at the White House this evening about next steps on Venezuela,       │
# │ sources told CNN [1].                                                                                           │
# │                                                                                                                 │
# │ Donald Trump is the 47th and current president since January 20, 2025 [2].                                      │
# │                                                                                                                 │
# │ President Trump Makes an Announcement, Dec. 2, 2025 ... President Trump Hosts a Cabinet Meeting, Dec. 2, 2025   │
# │ x.com/i/broadcasts/1… [3].                                                                                      │
# │                                                                                                                 │
# │ **List of All Relevant Sources (with citations in the report)**                                                 │
# │                                                                                                                 │
# │ [1] Trump administration news | CNN Politics:                                                                   │
# │ https://www.cnn.com/politics/live-news/trump-venezuela-ukraine-news-12-01-25                                    │
# │ [2] President of the United States - Wikipedia: https://en.wikipedia.org/wiki/President_of_the_United_States    │
# │ [3] President Donald J. Trump (@POTUS) / Posts / X - Twitter: https://x.com/POTUS                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: think_tool                                                                                        │
# │    Args: {                                                                                                      │
# │   "reflection": "1. Analysis of current findings - I found that Donald Trump is the current President of the    │
# │ United States, having taken office on January 20, 2025. There are recent reports about his activities,          │
# │ including a meeting regarding Venezuela. \n2. Gap assessment - There is no crucial information missing          │
# │ regarding who the current president is. \n3. Quality evaluation - I have sufficient evidence to confirm that    │
# │ Donald Trump is the president. \n4. Strategic decision - I have enough information to provide a complete        │
# │ answer."                                                                                                        │
# │ }                                                                                                               │
# │    ID: call_T3DOXGmWkCOJhS5KvtW2Y2SW                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Reflection recorded: 1. Analysis of current findings - I found that Donald Trump is the current President of    │
# │ the United States, having taken office on January 20, 2025. There are recent reports about his activities,      │
# │ including a meeting regarding Venezuela.                                                                        │
# │ 2. Gap assessment - There is no crucial information missing regarding who the current president is.             │
# │ 3. Quality evaluation - I have sufficient evidence to confirm that Donald Trump is the president.               │
# │ 4. Strategic decision - I have enough information to provide a complete answer.                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ResearchComplete                                                                                  │
# │    Args: {}                                                                                                     │
# │    ID: call_aFaNnFms0wjuf1yzB3XsgyjL                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Research Completed                                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "upcoming economic events December 2025"                                                    │
# │ }                                                                                                               │
# │    ID: call_SSCPbdAl6CPZGY9m4YD8m2sb                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ 1. Searched for "major economic events December 2025 central bank meetings economic reports financial           │
# │ conferences" to identify key economic events, central bank meetings, economic reports, and financial            │
# │ conferences scheduled for December 2025.                                                                        │
# │ 2. Searched for "economic reports December 2025 financial conferences central bank meetings" to find additional │
# │ details on economic reports and financial conferences.                                                          │
# │ 3. Searched for "financial conferences December 2025 economic reports schedule" to identify specific financial  │
# │ conferences and economic report schedules.                                                                      │
# │ 4. Searched for "economic reports release schedule December 2025" to obtain a detailed schedule of economic     │
# │ reports for December 2025.                                                                                      │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ **Fully Comprehensive Findings**                                                                                │
# │                                                                                                                 │
# │ - The Federal Reserve Board provides a calendar for December 2025, which includes information on Federal        │
# │ Reserve Banks, speeches, testimony, monetary policy, supervision & regulation, the Federal Reserve Supervision  │
# │ and Regulation Report, Federal Reserve's Key Policies for the Provision of Financial Services, Supervision &    │
# │ Oversight of Financial Market Infrastructures, and various data releases such as H.8, Structure and Share Data  │
# │ for the U.S. Offices of Foreign Banks, Finance Companies - G.20, Statistics Reported by Banks and Other         │
# │ Financial Firms in the United States, Consumer Credit - G.19, and Industrial Production and Capacity            │
# │ Utilization - G.17. [1]                                                                                         │
# │                                                                                                                 │
# │ - After lowering rates by 25 basis points in both September and October, Chair Jerome Powell has made it clear  │
# │ that another rate cut before the end of the year isn’t necessarily a given. In fact, minutes from the October   │
# │ Fed meeting show that officials are deeply divided on next steps. Fed Governor Stephen Miran, who has been      │
# │ advocating for rate cuts, told CNBC in an interview on November 10, “Failing new information that’s made me     │
# │ update my forecasts, looking out in time, yeah, I would think that 50  is appropriate, as I have in the past,   │
# │ but at a minimum 25.” [2]                                                                                       │
# │                                                                                                                 │
# │ - The FOMC Meeting in December 2025 is scheduled as a two-day meeting of the Federal Open Market Committee      │
# │ (FOMC), during which officials will decide on the Fed rate cut, economic projection for the coming months, and  │
# │ the potential start of quantitative easing (QE). The crypto market is particularly attentive to this meeting,   │
# │ as the Fed's actions could set the direction for global markets. [3]                                            │
# │                                                                                                                 │
# │ - The Bank of England will hold a Financial Stability Report Press Conference in December 2025. The Financial   │
# │ Policy Committee (FPC) identifies, monitors, and takes action to remove or reduce systemic risks with a view to │
# │ protecting and enhancing the resilience of the UK financial system. The FPC also has a secondary objective to   │
# │ support the economic policy of the Government. Twice a year, the FPC publishes a Financial Stability Report,    │
# │ which sets out the committee’s view on the main risks to financial stability and assesses how prepared the      │
# │ financial system is to withstand these risks. A transcript of the press conference is available on the Bank of  │
# │ England website. [4]                                                                                            │
# │                                                                                                                 │
# │ - The weekly economic calendar for December 8–14, 2025, includes the following central bank meetings:           │
# │   - 03:30 – AUD: Reserve Bank of Australia's Interest Rate Decision.                                            │
# │   - 14:45 – CAD: Bank of Canada Interest Rate Decision and Accompanying Statement.                              │
# │   - The financial market may experience higher volatility when the rate decision is announced, particularly in  │
# │ the US stock market and the US dollar, especially if the rate decision does not match the forecast or the Fed   │
# │ makes unexpected statements. The Fed's forecasts for interest rates, inflation, and economic growth over the    │
# │ next 1–2 years and beyond will draw significant attention. The Reserve Bank of Australia has repeatedly stated  │
# │ that the Australian economy and the central bank's plans are influenced by key indicators like the level of     │
# │ household debt and spending, wage growth, and the state of the labor market, in addition to the international   │
# │ trade situation. [5]                                                                                            │
# │                                                                                                                 │
# │ - The New York Fed offers the Central Banking Seminar and several specialized courses for central bankers and   │
# │ financial supervisors in December 2025. [6]                                                                     │
# │                                                                                                                 │
# │ - Finance conferences in the USA are scheduled for December 2025. All Conference Alert is a platform where      │
# │ upcoming finance conferences in the USA for December 2025 can be found. The platform is used by PHD students,   │
# │ research scholars, researchers, academic professionals, and industry peers to find relevant conferences/events. │
# │ [7]                                                                                                             │
# │                                                                                                                 │
# │ - The Economic Release Calendar from FRED (St. Louis Fed) for the week of Nov 30 – Dec 6, 2025, includes:       │
# │   - 7:30 am, U.S. Import and Export Price Indexes                                                               │
# │   - Chicago Fed National Financial Conditions Index                                                             │
# │   - 8:00 am, Overnight Bank Funding Rate Data [8]                                                               │
# │                                                                                                                 │
# │ - The U.S. Census Bureau provides an Economic Indicator Release Schedule in list view, but the specific         │
# │ December 2025 reports are not detailed in the summary. [9]                                                      │
# │                                                                                                                 │
# │ - The U.S. Bureau of Labor Statistics (BLS) provides a schedule of selected releases for December 2025,         │
# │ including:                                                                                                      │
# │   - Consumer Price Index                                                                                        │
# │   - Employment Cost Index                                                                                       │
# │   - Employment Situation                                                                                        │
# │   - Producer Price Index                                                                                        │
# │   - Productivity and Costs                                                                                      │
# │   - Real Earnings                                                                                               │
# │   - State Employment and Unemployment                                                                           │
# │   - Business Employment Dynamics                                                                                │
# │   - County Employment and Wages [10]                                                                            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ **List of All Relevant Sources (with citations in the report)**                                                 │
# │                                                                                                                 │
# │ [1] Calendar: December 2025 - Federal Reserve Board:                                                            │
# │ https://www.federalreserve.gov/newsevents/2025-december.htm                                                     │
# │ [2] The Federal Reserve's December 2025 Meeting - Chase Bank:                                                   │
# │ https://www.chase.com/personal/investments/learning-and-insights/article/december-2025-federal-reserve-meeting- │
# │ expectations                                                                                                    │
# │ [3] FOMC Meeting December 2025 Schedule, Key Expectations and ...:                                              │
# │ https://coingape.com/fomc-meeting-december-2025-schedule-key-expectations-and-interest-rate-outlook/            │
# │ [4] Financial Stability Report Press Conference, December 2025: https://www.youtube.com/watch?v=oFJ39qrAfjk     │
# │ [5] Weekly Economic Calendar for 08.12.2025–14.12.2025 - LiteFinance:                                           │
# │ https://www.litefinance.org/blog/analysts-opinions/weekly-economic-calendar-for-08122025-14122025/              │
# │ [6] Economic Indicators Calendar | New York Fed: https://www.newyorkfed.org/research/calendars/i-dec25.html     │
# │ [7] Upcoming Finance Conferences in USA December 2025:                                                          │
# │ https://www.allconferencealert.com/usa/finance-conference/december                                              │
# │ [8] Economic Release Calendar | FRED | St. Louis Fed: https://fred.stlouisfed.org/releases/calendar             │
# │ [9] Economic Indicator Release Schedule: List View:                                                             │
# │ https://www.census.gov/economic-indicators/calendar-listview.html                                               │
# │ [10] Schedule of Selected Releases for December 2025: https://www.bls.gov/schedule/                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: think_tool                                                                                        │
# │    Args: {                                                                                                      │
# │   "reflection": "1. Analysis of current findings: I found a comprehensive list of upcoming economic events in   │
# │ December 2025, including key meetings of the Federal Reserve and other central banks, important economic        │
# │ reports, and financial conferences. Notably, the FOMC meeting will be crucial for determining interest rates    │
# │ and economic projections, which could significantly impact the economy. Additionally, the Bank of England's     │
# │ Financial Stability Report will address systemic risks in the UK financial system. \n\n2. Gap assessment: While │
# │ I have a good overview of the scheduled events, I still need to assess how these events might specifically      │
# │ impact the macroeconomic landscape, such as potential market reactions or implications for economic policy.     │
# │ \n\n3. Quality evaluation: I have sufficient evidence and examples of upcoming events to provide a basic answer │
# │ regarding future events that might affect the current economic status. \n\n4. Strategic decision: I should      │
# │ summarize the findings and provide an answer, as I have gathered enough information to address the query        │
# │ comprehensively."                                                                                               │
# │ }                                                                                                               │
# │    ID: call_EyVXjJwLTzHynR67tdJOLYKu                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Reflection recorded: 1. Analysis of current findings: I found a comprehensive list of upcoming economic events  │
# │ in December 2025, including key meetings of the Federal Reserve and other central banks, important economic     │
# │ reports, and financial conferences. Notably, the FOMC meeting will be crucial for determining interest rates    │
# │ and economic projections, which could significantly impact the economy. Additionally, the Bank of England's     │
# │ Financial Stability Report will address systemic risks in the UK financial system.                              │
# │                                                                                                                 │
# │ 2. Gap assessment: While I have a good overview of the scheduled events, I still need to assess how these       │
# │ events might specifically impact the macroeconomic landscape, such as potential market reactions or             │
# │ implications for economic policy.                                                                               │
# │                                                                                                                 │
# │ 3. Quality evaluation: I have sufficient evidence and examples of upcoming events to provide a basic answer     │
# │ regarding future events that might affect the current economic status.                                          │
# │                                                                                                                 │
# │ 4. Strategic decision: I should summarize the findings and provide an answer, as I have gathered enough         │
# │ information to address the query comprehensively.                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ResearchComplete                                                                                  │
# │    Args: {}                                                                                                     │
# │    ID: call_wQvqBKqoWWJQ73Hz5hu2L56V                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Research Completed                                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from rich.console import Console
from rich.markdown import Markdown

console = Console()
md = Markdown(result["current_state_summary"])
console.print(md)
# Out:
# List of Queries and Tool Calls Made
#
#  • Query: "current US President December 2025"
#
# Fully Comprehensive Findings
#
# President Donald Trump will hold a meeting at the White House this evening about next steps on Venezuela, sources
# told CNN [1].
#
# Donald Trump is the 47th and current president since January 20, 2025 [2].
#
# President Trump Makes an Announcement, Dec. 2, 2025 ... President Trump Hosts a Cabinet Meeting, Dec. 2, 2025
# x.com/i/broadcasts/1… [3].
#
# List of All Relevant Sources (with citations in the report)
#
# [1] Trump administration news | CNN Politics:
# https://www.cnn.com/politics/live-news/trump-venezuela-ukraine-news-12-01-25
# [2] President of the United States - Wikipedia: https://en.wikipedia.org/wiki/President_of_the_United_States
# [3] President Donald J. Trump (@POTUS) / Posts / X - Twitter: https://x.com/POTUS

# %%
console = Console()
md = Markdown(result["future_events_summary"])
console.print(md)
# Out:
# List of Queries and Tool Calls Made
#
#  1 Searched for "major economic events December 2025 central bank meetings economic reports financial conferences"
#    to identify key economic events, central bank meetings, economic reports, and financial conferences scheduled
#    for December 2025.
#  2 Searched for "economic reports December 2025 financial conferences central bank meetings" to find additional
#    details on economic reports and financial conferences.
#  3 Searched for "financial conferences December 2025 economic reports schedule" to identify specific financial
#    conferences and economic report schedules.
#  4 Searched for "economic reports release schedule December 2025" to obtain a detailed schedule of economic reports
#    for December 2025.
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Fully Comprehensive Findings
#
#  • The Federal Reserve Board provides a calendar for December 2025, which includes information on Federal Reserve
#    Banks, speeches, testimony, monetary policy, supervision & regulation, the Federal Reserve Supervision and
#    Regulation Report, Federal Reserve's Key Policies for the Provision of Financial Services, Supervision &
#    Oversight of Financial Market Infrastructures, and various data releases such as H.8, Structure and Share Data
#    for the U.S. Offices of Foreign Banks, Finance Companies - G.20, Statistics Reported by Banks and Other
#    Financial Firms in the United States, Consumer Credit - G.19, and Industrial Production and Capacity Utilization
#    - G.17. [1]
#  • After lowering rates by 25 basis points in both September and October, Chair Jerome Powell has made it clear
#    that another rate cut before the end of the year isn’t necessarily a given. In fact, minutes from the October
#    Fed meeting show that officials are deeply divided on next steps. Fed Governor Stephen Miran, who has been
#    advocating for rate cuts, told CNBC in an interview on November 10, “Failing new information that’s made me
#    update my forecasts, looking out in time, yeah, I would think that 50 [basis points] is appropriate, as I have
#    in the past, but at a minimum 25.” [2]
#  • The FOMC Meeting in December 2025 is scheduled as a two-day meeting of the Federal Open Market Committee (FOMC),
#    during which officials will decide on the Fed rate cut, economic projection for the coming months, and the
#    potential start of quantitative easing (QE). The crypto market is particularly attentive to this meeting, as the
#    Fed's actions could set the direction for global markets. [3]
#  • The Bank of England will hold a Financial Stability Report Press Conference in December 2025. The Financial
#    Policy Committee (FPC) identifies, monitors, and takes action to remove or reduce systemic risks with a view to
#    protecting and enhancing the resilience of the UK financial system. The FPC also has a secondary objective to
#    support the economic policy of the Government. Twice a year, the FPC publishes a Financial Stability Report,
#    which sets out the committee’s view on the main risks to financial stability and assesses how prepared the
#    financial system is to withstand these risks. A transcript of the press conference is available on the Bank of
#    England website. [4]
#  • The weekly economic calendar for December 8–14, 2025, includes the following central bank meetings:
#     • 03:30 – AUD: Reserve Bank of Australia's Interest Rate Decision.
#     • 14:45 – CAD: Bank of Canada Interest Rate Decision and Accompanying Statement.
#     • The financial market may experience higher volatility when the rate decision is announced, particularly in
#       the US stock market and the US dollar, especially if the rate decision does not match the forecast or the Fed
#       makes unexpected statements. The Fed's forecasts for interest rates, inflation, and economic growth over the
#       next 1–2 years and beyond will draw significant attention. The Reserve Bank of Australia has repeatedly
#       stated that the Australian economy and the central bank's plans are influenced by key indicators like the
#       level of household debt and spending, wage growth, and the state of the labor market, in addition to the
#       international trade situation. [5]
#  • The New York Fed offers the Central Banking Seminar and several specialized courses for central bankers and
#    financial supervisors in December 2025. [6]
#  • Finance conferences in the USA are scheduled for December 2025. All Conference Alert is a platform where
#    upcoming finance conferences in the USA for December 2025 can be found. The platform is used by PHD students,
#    research scholars, researchers, academic professionals, and industry peers to find relevant conferences/events.
#    [7]
#  • The Economic Release Calendar from FRED (St. Louis Fed) for the week of Nov 30 – Dec 6, 2025, includes:
#     • 7:30 am, U.S. Import and Export Price Indexes
#     • Chicago Fed National Financial Conditions Index
#     • 8:00 am, Overnight Bank Funding Rate Data [8]
#  • The U.S. Census Bureau provides an Economic Indicator Release Schedule in list view, but the specific December
#    2025 reports are not detailed in the summary. [9]
#  • The U.S. Bureau of Labor Statistics (BLS) provides a schedule of selected releases for December 2025, including:
#     • Consumer Price Index
#     • Employment Cost Index
#     • Employment Situation
#     • Producer Price Index
#     • Productivity and Costs
#     • Real Earnings
#     • State Employment and Unemployment
#     • Business Employment Dynamics
#     • County Employment and Wages [10]
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# List of All Relevant Sources (with citations in the report)
#
# [1] Calendar: December 2025 - Federal Reserve Board: https://www.federalreserve.gov/newsevents/2025-december.htm
# [2] The Federal Reserve's December 2025 Meeting - Chase Bank:
# https://www.chase.com/personal/investments/learning-and-insights/article/december-2025-federal-reserve-meeting-expe
# ctations
# [3] FOMC Meeting December 2025 Schedule, Key Expectations and ...:
# https://coingape.com/fomc-meeting-december-2025-schedule-key-expectations-and-interest-rate-outlook/
# [4] Financial Stability Report Press Conference, December 2025: https://www.youtube.com/watch?v=oFJ39qrAfjk
# [5] Weekly Economic Calendar for 08.12.2025–14.12.2025 - LiteFinance:
# https://www.litefinance.org/blog/analysts-opinions/weekly-economic-calendar-for-08122025-14122025/
# [6] Economic Indicators Calendar | New York Fed: https://www.newyorkfed.org/research/calendars/i-dec25.html
# [7] Upcoming Finance Conferences in USA December 2025:
# https://www.allconferencealert.com/usa/finance-conference/december
# [8] Economic Release Calendar | FRED | St. Louis Fed: https://fred.stlouisfed.org/releases/calendar
# [9] Economic Indicator Release Schedule: List View:
# https://www.census.gov/economic-indicators/calendar-listview.html
# [10] Schedule of Selected Releases for December 2025: https://www.bls.gov/schedule/
